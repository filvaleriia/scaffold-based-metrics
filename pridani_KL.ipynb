# %%
import pandas as pd
import numpy as np

# %%
for generator_name in ['Molpher', 'DrugEx_GT_epsilon_0.1','DrugEx_GT_epsilon_0.6']:
    for type_split in ['dis']:
        for type_scaffold in ['csk']:
            def_gen_1 = []
            def_gen_2 = []
            for x in [0,1,2,3,4]:    
                df_KL= pd.read_csv(f"data/distributions/results_distributions_only/{generator_name}/df_KL_similarity_{type_scaffold}_{type_split}_{x}")
                def_gen_1.append(df_KL[df_KL.generator == generator_name][['KL_OS_IS']].values.flatten()[0])

                
            a = np.mean(def_gen_1)

            
            def_gen_1.append(a)

            
            
                
            df_gen = pd.read_csv(f"data/results/Glucocorticoid_receptor/{type_scaffold}_scaffolds/{type_split}/{generator_name}/df_all_clusters_with_med_with_mean.csv")
            df_gen['KL_OS_IS'] = def_gen_1

            
            mean = pd.DataFrame()
            mean = df_gen.loc[5].to_frame().T
            #df_gen.to_csv(f"data/results/Glucocorticoid_receptor/{type_scaffold}_scaffolds/{type_split}/{generator_name}/df_all_clusters_with_KL_with_mean.csv", index=False)
            #mean.to_csv(f"data/results/Glucocorticoid_receptor/{type_scaffold}_scaffolds/{type_split}/{generator_name}_mean_with_KL_{type_scaffold}_{type_split}.csv", index=False) #float_format='%.7f'
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 7
#       5 def_gen_2 = []
#       6 for x in [0,1,2,3,4]:
# ----> 7     df_KL= pd.read_csv(f"cluster/distributions/results_distributions_only/{generator_name}/df_KL_similarity_{type_scaffold}_{type_split}_{x}")
#       8     def_gen_1.append(df_KL[df_KL.generator == generator_name][['KL_OS_IS']].values.flatten()[0])
#      11 a = np.mean(def_gen_1)
#
# File ~/.conda/envs/drugex/lib/python3.10/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~/.conda/envs/drugex/lib/python3.10/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~/.conda/envs/drugex/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~/.conda/envs/drugex/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~/.conda/envs/drugex/lib/python3.10/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'cluster/distributions/results_distributions_only/Molpher/df_KL_similarity_csk_dis_0'

# %%
mean
# Out:
#                          name type_cluster scaffold       USo       SSo  \
# 5  DrugEx_GT_epsilon_0.6_mean          dis      csk  267648.0  907474.4
#
#   TUPOR_     TUPOR TUPOR_unique   TUPOR_1   TUPOR_2      SESY      ASER  \
# 5      -  0.679649     0.025317  0.000147  1.055034  0.294816  0.007886
#
#     CwASo  metric_1  metric_2  KL_OS_IS  KL_OS_RS
# 5  7186.4  0.000092  0.007986  0.000751  0.025066

# %%
df_gen = pd.read_csv("data/results/Glucocorticoid_receptor/csk_scaffolds/dis/Molpher/df_all_clusters_with_mean.csv")
df_gen
# Out:
#            name type_cluster scaffold       USo        SSo TUPOR_     TUPOR  \
# 0     Molpher_0          dis      csk  104715.0   916546.0  15/40  0.375000
# 1     Molpher_1          dis      csk  119055.0  1070030.0  15/23  0.652174
# 2     Molpher_2          dis      csk  105240.0   906891.0   9/40  0.225000
# 3     Molpher_3          dis      csk   89696.0   693460.0  20/37  0.540540
# 4     Molpher_4          dis      csk   81634.0   532962.0  34/43  0.790698
# 5  Molpher_mean          dis      csk  100068.0   823977.8      -  0.516682
#
#    TUPOR_unique   TUPOR_1   TUPOR_2      SESY      ASER   CwASo  metric_1  \
# 0      0.035812  0.000074  0.192796  0.114250  0.003291  3016.0  0.000143
# 1      0.054779  0.000038  0.198760  0.111263  0.001106  1183.0  0.000126
# 2      0.021380  0.000046  0.121412  0.116045  0.000114   103.0  0.000086
# 3      0.060264  0.000179  0.432727  0.129346  0.006726  4664.0  0.000223
# 4      0.096859  0.000451  0.856230  0.153170  0.011708  6240.0  0.000417
# 5      0.053819  0.000158  0.360385  0.124815  0.004589  3041.2  0.000199
#
#    metric_2
# 0  0.003302
# 1  0.001107
# 2  0.000114
# 3  0.006771
# 4  0.011847
# 5  0.004628

# %%
df_gen['KL_OS_IS'] = ['

# %%
df_KL_dis_0 = pd.read_csv("data/KL_divergence/df_KL_dis_0")
df_KL_dis_0
# Out:
#                  generator  KL_OS_IS  KL_OS_RS
# 0                  Molpher  0.404182  2.661215
# 1                 REINVENT  0.758605  2.952111
# 2                DrugEx_GT  0.377742  2.712360
# 3    DrugEx_GT_epsilon_0.1  0.756354  2.989940
# 4    DrugEx_GT_epsilon_0.6  0.405051  2.723309
# 5               DrugEx_RNN  0.568176  2.759121
# 6   DrugEx_RNN_epsilon_0.1  0.703502  2.879325
# 7   DrugEx_RNN_epsilon_0.6  0.518094  2.713713
# 8      DrugEx_epsilon_0.01  1.064774  3.556772
# 9       DrugEx_epsilon_0.1  0.832583  3.064448
# 10      DrugEx_epsilon_0.2  0.409366  2.658248
# 11      DrugEx_epsilon_0.4  0.370993  2.712992
# 12      DrugEx_epsilon_0.6  0.324838  2.678195

# %%
def connect_mean_value(reeptor, scaffold_type, type_cluster, generators_name_list):
    path = f"data/results/{receptor}/{scaffold_type}_scaffolds/{type_cluster}/"
    link = {}
    for generator in generators_name_list:
        link[f'link_{generator}'] = f'{path}{generator}_mean_with_KL_{scaffold_type}_{type_cluster}.csv'

    df = pd.DataFrame()
    for x,y in link.items():
        a = pd.read_csv(y)
        df = pd.concat([df, a], ignore_index=True)

    df = df.drop(columns = ['TUPOR_'])

    dff = df.copy()
    dff['SSo'] = dff['SSo'].apply(lambda x : "{:,}".format(x))
    dff['USo'] = dff['USo'].apply(lambda x : "{:,}".format(x))
    dff['CwASo'] = dff['CwASo'].apply(lambda x : "{:,}".format(x))

    
    dff.to_csv(f"{path}/mean_with_KL_{scaffold_type}_{type_cluster}_with_coma.csv", index = False)
    df.to_csv(f"{path}/mean_with_KL_{scaffold_type}_{type_cluster}.csv", index = False)
    dff.to_html(f"{path}/mean_with_KL_{scaffold_type}_{type_cluster}.html", index = False)

    
    display(df[['name','type_cluster','scaffold','USo',	'SSo','TUPOR', 'TUPOR_2', 'SESY','ASER','CwASo',	'metric_1',	'metric_2',	'KL_OS_IS']])
    return df

# %%
#type_cluster = 'dis' #options: 'dis'|'sim' 
#scaffold_type = 'csk' #options: 'csk'|'murcko'
#generators_name_list = [ 'Molpher', 'REINVENT'] #options: 'Molpher'|'DrugEx'
receptor = 'Glucocorticoid_receptor' #options: 'Glucocorticoid_receptor'|'Leukocyte_elastase'

generators_name_list= ['Molpher', 'DrugEx_GT_epsilon_0.1','DrugEx_GT_epsilon_0.6']
for type_cluster in ['dis']:
    for scaffold_type in ['csk']:
        df = connect_mean_value(receptor, scaffold_type, type_cluster, generators_name_list)
# Out:
#                          name type_cluster scaffold       USo       SSo  \
# 0                Molpher_mean          dis      csk  100068.0  823977.8
# 1  DrugEx_GT_epsilon_0.1_mean          dis      csk  140428.0  809233.2
# 2  DrugEx_GT_epsilon_0.6_mean          dis      csk  267648.0  907474.4
#
#       TUPOR   TUPOR_2      SESY      ASER   CwASo  metric_1  metric_2  \
# 0  0.516682  0.360385  0.124815  0.004589  3041.2  0.000199  0.004628
# 1  0.545466  0.511284  0.172969  0.004915  4063.2  0.000137  0.004957
# 2  0.679649  1.055034  0.294816  0.007886  7186.4  0.000092  0.007986
#
#    KL_OS_IS
# 0  0.001139
# 1  0.002958
# 2  0.000751
