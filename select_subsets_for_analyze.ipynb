# %% [markdown]
# # Subset selection for analysis to determine the optimal number of sets:
# #### Originally, we generated a virtual library of 1 million compounds. However, for some generators, this process is very time-consuming. Therefore, we decided to explore different subset sizes—10 000, 100 000, and 500 000—to identify the optimal size.

# %%
import pandas as pd
from itertools import combinations
import os

# %% [markdown]
# # Molpher generator:
# #### For the Molpher generator, we need to select the entire path for random selection because Molpher creates a path between the starting molecule and the target molecule.

# %%
# Loop through different parameters for data processing
receptor = 'Leukocyte_elastase'
for type_split in ['dis', 'sim']:
    for number in [0, 1, 2, 3, 4]:
        for target in [10_000, 100_000, 500_000]:
            
            # Load the dataset
            df = pd.read_csv(f"data/output_sets/{receptor}/Molpher/cOS_Molpher_{type_split}_{number}_all_columns.csv", header=None)
            df.columns = ['id_input', 'id_output', 'smiles_input', 'smiles_output', 'molpher', 'TC', 'count', 'time', 'scaf_input', 'scaf_output']
            
            # Group data by 'id_input' and 'id_output', keeping the first values of 'count' and 'molpher'
            grouped = df.groupby(['id_input', 'id_output']).agg({
                'count': 'first',    # Keep the first 'count' value
                'molpher': 'first'   # Keep the first 'molpher' value
            }).reset_index()
            
            # Target sum for selection
            
            def random_selection(df, target):
                """
                Function to randomly select rows from the DataFrame until their count sum reaches the target value.
                """
                selected_rows = []
                selected_rows_idx = []
                current_sum = 0
                
                # Perform random selection until the count sum reaches the target
                while current_sum < target:
                    random_row = df.sample(n=1)  # Select a random row

                    if random_row.index.item() not in selected_rows_idx:
                        selected_rows_idx.append(random_row.index.item())
                        selected_rows.append(random_row)
                        current_sum += random_row['count'].values[0]  # Add the 'count' value to the total
                
                # Concatenate all selected rows into a new DataFrame
                result_df = pd.concat(selected_rows, ignore_index=True)
                return result_df, current_sum
            
            # Apply the random selection function
            result, total_sum = random_selection(grouped, target)
            
            print(f"Selected combination ({len(result)} rows):")
            print(f"Total count sum: {total_sum}")
            
            # Extract id_input and id_output from the selected results
            ids_to_filter = result[['id_input', 'id_output']]
            
            # Filter the original DataFrame based on the selected id_input and id_output
            filtered_df = df[df[['id_input', 'id_output']].apply(tuple, axis=1).isin(ids_to_filter.apply(tuple, axis=1))]
            
            print("\nFiltering the original DataFrame based on id_input and id_output:")
            
            # Reset index for the filtered DataFrame
            filtered_df = filtered_df.reset_index(drop=True)
            
            # Extract 'molpher' column for the output
            morphs = filtered_df['molpher']
            print(f"Number of selected morphs: {len(morphs)}")
            
            # Convert target to string format for file naming
            target_str = {10_000: '10k', 100_000: '100k', 500_000: '500k'}.get(target, str(target))
            
            # Save the selected 'molpher' values to a CSV file
            folder = f"data/output_sets/{receptor}/Molpher_{target_str}"
            if not os.path.exists(folder):
                os.makedirs(folder)
            output_path = f"{folder}/cOS_Molpher_{target_str}_{type_split}_{number}_one_column.csv"
            morphs.to_csv(output_path, index=False, header=False)
            print(f"Output saved to {output_path}\n")
# Out:
# Selected combination (96 rows):
# Total count sum: 10058
#
# Filtering the original DataFrame based on id_input and id_output:
# Number of selected morphs: 10058
# Output saved to data/output_sets/Leukocyte_elastase/Molpher_10k/cOS_Molpher_10k_dis_0_one_column.csv
#
# Selected combination (831 rows):
# Total count sum: 100043
#
# Filtering the original DataFrame based on id_input and id_output:
# Number of selected morphs: 100043
# Output saved to data/output_sets/Leukocyte_elastase/Molpher_100k/cOS_Molpher_100k_dis_0_one_column.csv
#
# Selected combination (4190 rows):
# Total count sum: 500173
#
# Filtering the original DataFrame based on id_input and id_output:
# Number of selected morphs: 500173
# Output saved to data/output_sets/Leukocyte_elastase/Molpher_500k/cOS_Molpher_500k_dis_0_one_column.csv
#
# Selected combination (88 rows):
# Total count sum: 10243
#
# Filtering the original DataFrame based on id_input and id_output:
# Number of selected morphs: 10243
# Output saved to data/output_sets/Leukocyte_elastase/Molpher_10k/cOS_Molpher_10k_dis_1_one_column.csv
#
# Selected combination (836 rows):
# Total count sum: 100215
#
# Filtering the original DataFrame based on id_input and id_output:
# Number of selected morphs: 100215
# Output saved to data/output_sets/Leukocyte_elastase/Molpher_100k/cOS_Molpher_100k_dis_1_one_column.csv
#
# Selected combination (4368 rows):
# Total count sum: 500028
#
# Filtering the original DataFrame based on id_input and id_output:
# Number of selected morphs: 500028
# Output saved to data/output_sets/Leukocyte_elastase/Molpher_500k/cOS_Molpher_500k_dis_1_one_column.csv
#
# Selected combination (91 rows):
# Total count sum: 10137
#
# Filtering the original DataFrame based on id_input and id_output:
# Number of selected morphs: 10137
# Output saved to data/output_sets/Leukocyte_elastase/Molpher_10k/cOS_Molpher_10k_dis_2_one_column.csv
#
# Selected combination (824 rows):
# Total count sum: 100165
#
# Filtering the original DataFrame based on id_input and id_output:
# Number of selected morphs: 100165
# Output saved to data/output_sets/Leukocyte_elastase/Molpher_100k/cOS_Molpher_100k_dis_2_one_column.csv
#
# Selected combination (4095 rows):
# Total count sum: 500134
#
# Filtering the original DataFrame based on id_input and id_output:
# Number of selected morphs: 500134
# Output saved to data/output_sets/Leukocyte_elastase/Molpher_500k/cOS_Molpher_500k_dis_2_one_column.csv
#
# Selected combination (77 rows):
# Total count sum: 10025
#
# Filtering the original DataFrame based on id_input and id_output:
# Number of selected morphs: 10025
# Output saved to data/output_sets/Leukocyte_elastase/Molpher_10k/cOS_Molpher_10k_dis_3_one_column.csv
#
# Selected combination (928 rows):
# Total count sum: 100029
#
# Filtering the original DataFrame based on id_input and id_output:
# Number of selected morphs: 100029
# Output saved to data/output_sets/Leukocyte_elastase/Molpher_100k/cOS_Molpher_100k_dis_3_one_column.csv
#
# Selected combination (4335 rows):
# Total count sum: 500093
#
# Filtering the original DataFrame based on id_input and id_output:
# Number of selected morphs: 500093
# Output saved to data/output_sets/Leukocyte_elastase/Molpher_500k/cOS_Molpher_500k_dis_3_one_column.csv
#
# Selected combination (81 rows):
# Total count sum: 10084
#
# Filtering the original DataFrame based on id_input and id_output:
# Number of selected morphs: 10084
# Output saved to data/output_sets/Leukocyte_elastase/Molpher_10k/cOS_Molpher_10k_dis_4_one_column.csv
#
# Selected combination (784 rows):
# Total count sum: 100004
#
# Filtering the original DataFrame based on id_input and id_output:
# Number of selected morphs: 100004
# Output saved to data/output_sets/Leukocyte_elastase/Molpher_100k/cOS_Molpher_100k_dis_4_one_column.csv
#
# Selected combination (3967 rows):
# Total count sum: 500149
#
# Filtering the original DataFrame based on id_input and id_output:
# Number of selected morphs: 500149
# Output saved to data/output_sets/Leukocyte_elastase/Molpher_500k/cOS_Molpher_500k_dis_4_one_column.csv
#
# Selected combination (89 rows):
# Total count sum: 10122
#
# Filtering the original DataFrame based on id_input and id_output:
# Number of selected morphs: 10122
# Output saved to data/output_sets/Leukocyte_elastase/Molpher_10k/cOS_Molpher_10k_sim_0_one_column.csv
#
# Selected combination (801 rows):
# Total count sum: 100031
#
# Filtering the original DataFrame based on id_input and id_output:
# Number of selected morphs: 100031
# Output saved to data/output_sets/Leukocyte_elastase/Molpher_100k/cOS_Molpher_100k_sim_0_one_column.csv
#
# Selected combination (4073 rows):
# Total count sum: 500053
#
# Filtering the original DataFrame based on id_input and id_output:
# Number of selected morphs: 500053
# Output saved to data/output_sets/Leukocyte_elastase/Molpher_500k/cOS_Molpher_500k_sim_0_one_column.csv
#
# Selected combination (75 rows):
# Total count sum: 10025
#
# Filtering the original DataFrame based on id_input and id_output:
# Number of selected morphs: 10025
# Output saved to data/output_sets/Leukocyte_elastase/Molpher_10k/cOS_Molpher_10k_sim_1_one_column.csv
#
# Selected combination (802 rows):
# Total count sum: 100096
#
# Filtering the original DataFrame based on id_input and id_output:
# Number of selected morphs: 100096
# Output saved to data/output_sets/Leukocyte_elastase/Molpher_100k/cOS_Molpher_100k_sim_1_one_column.csv
#
# Selected combination (4125 rows):
# Total count sum: 500023
#
# Filtering the original DataFrame based on id_input and id_output:
# Number of selected morphs: 500023
# Output saved to data/output_sets/Leukocyte_elastase/Molpher_500k/cOS_Molpher_500k_sim_1_one_column.csv
#
# Selected combination (87 rows):
# Total count sum: 10065
#
# Filtering the original DataFrame based on id_input and id_output:
# Number of selected morphs: 10065
# Output saved to data/output_sets/Leukocyte_elastase/Molpher_10k/cOS_Molpher_10k_sim_2_one_column.csv
#
# Selected combination (833 rows):
# Total count sum: 100195
#
# Filtering the original DataFrame based on id_input and id_output:
# Number of selected morphs: 100195
# Output saved to data/output_sets/Leukocyte_elastase/Molpher_100k/cOS_Molpher_100k_sim_2_one_column.csv
#
# Selected combination (4242 rows):
# Total count sum: 500098
#
# Filtering the original DataFrame based on id_input and id_output:
# Number of selected morphs: 500098
# Output saved to data/output_sets/Leukocyte_elastase/Molpher_500k/cOS_Molpher_500k_sim_2_one_column.csv
#
# Selected combination (95 rows):
# Total count sum: 10150
#
# Filtering the original DataFrame based on id_input and id_output:
# Number of selected morphs: 10150
# Output saved to data/output_sets/Leukocyte_elastase/Molpher_10k/cOS_Molpher_10k_sim_3_one_column.csv
#
# Selected combination (781 rows):
# Total count sum: 100060
#
# Filtering the original DataFrame based on id_input and id_output:
# Number of selected morphs: 100060
# Output saved to data/output_sets/Leukocyte_elastase/Molpher_100k/cOS_Molpher_100k_sim_3_one_column.csv
#
# Selected combination (3993 rows):
# Total count sum: 500093
#
# Filtering the original DataFrame based on id_input and id_output:
# Number of selected morphs: 500093
# Output saved to data/output_sets/Leukocyte_elastase/Molpher_500k/cOS_Molpher_500k_sim_3_one_column.csv
#
# Selected combination (80 rows):
# Total count sum: 10151
#
# Filtering the original DataFrame based on id_input and id_output:
# Number of selected morphs: 10151
# Output saved to data/output_sets/Leukocyte_elastase/Molpher_10k/cOS_Molpher_10k_sim_4_one_column.csv
#
# Selected combination (812 rows):
# Total count sum: 100069
#
# Filtering the original DataFrame based on id_input and id_output:
# Number of selected morphs: 100069
# Output saved to data/output_sets/Leukocyte_elastase/Molpher_100k/cOS_Molpher_100k_sim_4_one_column.csv
#
# Selected combination (4032 rows):
# Total count sum: 500119
#
# Filtering the original DataFrame based on id_input and id_output:
# Number of selected morphs: 500119
# Output saved to data/output_sets/Leukocyte_elastase/Molpher_500k/cOS_Molpher_500k_sim_4_one_column.csv

# %% [markdown]
# # Other generators:
# #### random seletion for other generators

# %%
# Iterate through different molecular generators
receptor = 'Leukocyte_elastase'
for generator in [
     'GB_GA_mut_r_0.5'
]:
    # Iterate through different types of splitting methods
    for type_split in [ 'dis']:
        # Iterate through different dataset numbers
        for number in [0, 1, 2, 3, 4]:
            # Iterate through different target sizes
            for target in [10_000, 100_000, 500_000]:
                random_smiles = None

                # Read the input dataset
                df = pd.read_csv(
                    f"data/output_sets/{receptor}/{generator}/cOS_{generator}_{type_split}_{number}_one_column.csv",
                    header=None
                )
                df.columns = ['smiles']  # Assign column name
                
                # Randomly sample the specified number of molecules
                random_smiles = df['smiles'].sample(n=target, random_state=42).reset_index(drop=True)

                # Convert numerical target size to a readable string
                target_str = {10_000: '10k', 100_000: '100k', 500_000: '500k'}.get(target, str(target))
                
                # Save the sampled molecules to a new CSV file
                folder = f"data/output_sets/{receptor}/{generator}_{target_str}"

                if not os.path.exists(folder):
                    os.makedirs(folder)
                random_smiles.to_csv(
                    f"{folder}/cOS_{generator}_{target_str}_{type_split}_{number}_one_column.csv",
                    index=False, header=False
                )
