# %%
import pandas as pd
import rdkit
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole
import itertools
from rdkit import DataStructs
from rdkit.Chem.Scaffolds.MurckoScaffold import MakeScaffoldGeneric
from rdkit.Chem.Scaffolds.MurckoScaffold import MurckoScaffoldSmiles
from rdkit.Chem import AllChem
import numpy as np

# %% [markdown]
# # Showing scaffolds in each cluster for each generators

# %%
receptor = 'Leukocyte_elastase'
df = pd.read_csv(f"data/input_recall_sets_new/{receptor}/{receptor}_split_to_clusters_using_KMedoids.csv")
df
# Out:
#      molregno stand_type  pchembl_value  stand_value  \
# 0     2135949       IC50           7.18         66.0
# 1     2108566       IC50           7.70         20.0
# 2     2116233       IC50           7.38         42.0
# 3     2526639       IC50           7.05         89.0
# 4     2192565       IC50           8.42          3.8
# ..        ...        ...            ...          ...
# 211   2165415       IC50           8.52          3.0
# 212   2320305       IC50           6.10        800.0
# 213     69173       IC50           6.64        230.0
# 214   2137653       IC50           8.41          3.9
# 215     88510       IC50          10.00          0.1
#
#                                       canonical_smiles  \
# 0    CC1CC2=C(C1=O)C(c1ccc(C#N)cc1)NC(=O)N2c1cccc(C...
# 1    Cc1c(-c2cccc(C(F)(F)F)c2)c(=O)c(C(=O)NCc2ccc(C...
# 2    COCCn1cc(C(=O)NCc2ccc(S(C)(=O)=O)cc2)c(=O)c(-c...
# 3                   Cc1cccc(C(=O)n2cc(C#N)c3ncccc32)c1
# 4    N#Cc1ccc(C2C3=C(CCC3=O)N(c3cccc(C(F)(F)F)c3)C(...
# ..                                                 ...
# 211  CCOC(=O)C1=C(C)N(c2cccc(C(F)(F)F)c2)C(=O)N(C)C...
# 212            O=C(Nc1ccccc1)c1cn(C(=O)C2CC2)c2ncccc12
# 213               Cc1ccc(N2C(=O)N(c3ccc(C)cc3)C2=O)cc1
# 214  CN1C(=O)N(c2cccc(C(F)(F)F)c2)C2=C(C(=O)CC2)C1c...
# 215         CC(SC(=O)c1cccs1)C(=O)NCC(=O)N1CSCC1C(=O)O
#
#                      stand_inchi      chembl_id  tid            pref_name  \
# 0    XVAKYHYZPKKXPJ-UHFFFAOYSA-N  CHEMBL3926578  235  Leukocyte elastase
# 1    GVZLHJFVWYZJOL-UHFFFAOYSA-N  CHEMBL3899195  235  Leukocyte elastase
# 2    MBIXKVGDRHLSCV-UHFFFAOYSA-N  CHEMBL3906862  235  Leukocyte elastase
# 3    YYSDWURRUMMAIG-UHFFFAOYSA-N  CHEMBL4790048  235  Leukocyte elastase
# 4    FFGCQYSSTYWKTM-UHFFFAOYSA-N  CHEMBL3983194  235  Leukocyte elastase
# ..                           ...            ...  ...                  ...
# 211  FPTMCPUSBLSGFP-UHFFFAOYSA-N  CHEMBL3956044  235  Leukocyte elastase
# 212  YAQCMERNUDLGCS-UHFFFAOYSA-N  CHEMBL4280854  235  Leukocyte elastase
# 213  AZZFGWWOGRBVOV-UHFFFAOYSA-N   CHEMBL296771  235  Leukocyte elastase
# 214  OZHWFTPSRFSWRF-UHFFFAOYSA-N  CHEMBL3928282  235  Leukocyte elastase
# 215  OFCXTUWNBCBZFB-UHFFFAOYSA-N   CHEMBL293138  235  Leukocyte elastase
#
#                                        scaffolds_csk  \
# 0                  C1CCC(C2CCC(C3CCCCC3)C3CCCC23)CC1
# 1          C1CCC(C2CCCC(CCCC3CCC(CC4CCCC4)CC3)C2)CC1
# 2                    C1CCC(CCCC2CCCC(C3CCCCC3)C2)CC1
# 3                           C1CCC(CC2CCC3CCCCC32)CC1
# 4        C1CCC(CCC2CC(C3CCCCC3)C3CCCC3C2C2CCCCC2)CC1
# ..                                               ...
# 211              C1CCC(C2CCC(C3CCCCC3CCC3CC3)CC2)CC1
# 212                C1CCC(CCC2CC(CC3CC3)C3CCCCC23)CC1
# 213                       C1CCC(C2CC(C3CCCCC3)C2)CC1
# 214  C1CCC(C2CCC(C3CCCCC3CC3CC4CCCCC4C3)C3CCCC23)CC1
# 215                          C(CCCC1CCCC1)CCCC1CCCC1
#
#                                                    mfp  clusters
# 0    <rdkit.DataStructs.cDataStructs.ExplicitBitVec...         0
# 1    <rdkit.DataStructs.cDataStructs.ExplicitBitVec...         1
# 2    <rdkit.DataStructs.cDataStructs.ExplicitBitVec...         1
# 3    <rdkit.DataStructs.cDataStructs.ExplicitBitVec...         4
# 4    <rdkit.DataStructs.cDataStructs.ExplicitBitVec...         1
# ..                                                 ...       ...
# 211  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...         2
# 212  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...         4
# 213  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...         1
# 214  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...         0
# 215  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...         3
#
# [216 rows x 12 columns]

# %%
for x in range(5):
    df_ = df[df.clusters==x]
    IPythonConsole.drawOptions.drawMolsSameScale=False
    mols=[Chem.MolFromSmiles(z) for z in df_.scaffolds_csk]
    d=Draw.MolsToGridImage(mols,molsPerRow=8, subImgSize=(180, 180), returnPNG=False)
    d.save(f"img/clusters/scaffolds_in_cluster_{x}_{receptor}.png")

# %% [markdown]
# # Calculate statistics about end runs for Molpher

# %%
good_runs_0 = 11039
good_runs_1 = 11013
good_runs_2 = 11093
good_runs_3 = 7755
good_runs_4 = 5814

# %%
all_runs_0 = 26732
all_runs_1 = 28730
all_runs_2 = 26732
all_runs_3 = 27390
all_runs_4 = 25440

# %%
df = pd.DataFrame(columns = ['all_runs', 'good_runs', 'percentage'])

# %%
df.loc[len(df.index)] = [all_runs_0,good_runs_0,f"{((good_runs_0/all_runs_0)*100):.1f}%"]
df.loc[len(df.index)] = [all_runs_1,good_runs_1,f"{((good_runs_1/all_runs_1)*100):.1f}%"]
df.loc[len(df.index)] = [all_runs_2,good_runs_2,f"{((good_runs_2/all_runs_2)*100):.1f}%"]
df.loc[len(df.index)] = [all_runs_3,good_runs_3,f"{((good_runs_3/all_runs_3)*100):.1f}%"]
df.loc[len(df.index)] = [all_runs_4,good_runs_4,f"{((good_runs_4/all_runs_4)*100):.1f}%"]
df
# Out:
#    all_runs  good_runs percentage
# 0     26732      11039      41.3%
# 1     28730      11013      38.3%
# 2     26732      11093      41.5%
# 3     27390       7755      28.3%
# 4     25440       5814      22.9%

# %%
df.to_csv("data/information_about_runs/Glucocorticoid_receptor/dis/information_about_runs.csv", index_label = False)

# %%
print(f"{31.655:.2f}")
# Out:
# 31.66

# %%
number = 4
type_split = 'sim'
dff = pd.read_csv(f'data/output_sets/Leukocyte_elastase/cOS_Molpher_{type_split}_{number}_all_columns.csv', header = None)
dff.columns = ['chembl_start', 'chembl_stop', 'start_smiles', 'stop_smiles', 'morph', 'tanimoto', 'length', 'time']
print(len(dff.groupby(['chembl_start', 'chembl_stop']).count()))

dff = pd.read_csv(f"data/input_recall_sets/Leukocyte_elastase/IS_Molpher_Leukocyte_elastase_{type_split}_{number}.csv")
len(dff)
# Out:
# 13970
# 30450

# %%
# FOR SIM SPLIT

good_runs_0 = 13130
good_runs_1 = 13664
good_runs_2 = 13026
good_runs_3 = 14398
good_runs_4 = 13970


all_runs_0 = 29070
all_runs_1 = 29756
all_runs_2 = 30102
all_runs_3 = 30450
all_runs_4 = 30450

df = pd.DataFrame(columns = ['all_runs', 'good_runs', 'percentage'])


df.loc[len(df.index)] = [all_runs_0,good_runs_0,f"{((good_runs_0/all_runs_0)*100):.1f}%"]
df.loc[len(df.index)] = [all_runs_1,good_runs_1,f"{((good_runs_1/all_runs_1)*100):.1f}%"]
df.loc[len(df.index)] = [all_runs_2,good_runs_2,f"{((good_runs_2/all_runs_2)*100):.1f}%"]
df.loc[len(df.index)] = [all_runs_3,good_runs_3,f"{((good_runs_3/all_runs_3)*100):.1f}%"]
df.loc[len(df.index)] = [all_runs_4,good_runs_4,f"{((good_runs_4/all_runs_4)*100):.1f}%"]
df


df.to_csv(f"data/information_about_runs/Leukocyte_elastase/{type_split}/information_about_runs.csv", index_label = False)

# %% [markdown]
# # Create statistics about input and between spilt

# %%
receptor = 'Leukocyte_elastase'
df = pd.read_csv(f"data/input_recall_sets_new/{receptor}/{receptor}_split_to_clusters_using_KMedoids.csv")
df
# Out:
#      molregno stand_type  pchembl_value  stand_value  \
# 0     2135949       IC50           7.18         66.0
# 1     2108566       IC50           7.70         20.0
# 2     2116233       IC50           7.38         42.0
# 3     2526639       IC50           7.05         89.0
# 4     2192565       IC50           8.42          3.8
# ..        ...        ...            ...          ...
# 211   2165415       IC50           8.52          3.0
# 212   2320305       IC50           6.10        800.0
# 213     69173       IC50           6.64        230.0
# 214   2137653       IC50           8.41          3.9
# 215     88510       IC50          10.00          0.1
#
#                                       canonical_smiles  \
# 0    CC1CC2=C(C1=O)C(c1ccc(C#N)cc1)NC(=O)N2c1cccc(C...
# 1    Cc1c(-c2cccc(C(F)(F)F)c2)c(=O)c(C(=O)NCc2ccc(C...
# 2    COCCn1cc(C(=O)NCc2ccc(S(C)(=O)=O)cc2)c(=O)c(-c...
# 3                   Cc1cccc(C(=O)n2cc(C#N)c3ncccc32)c1
# 4    N#Cc1ccc(C2C3=C(CCC3=O)N(c3cccc(C(F)(F)F)c3)C(...
# ..                                                 ...
# 211  CCOC(=O)C1=C(C)N(c2cccc(C(F)(F)F)c2)C(=O)N(C)C...
# 212            O=C(Nc1ccccc1)c1cn(C(=O)C2CC2)c2ncccc12
# 213               Cc1ccc(N2C(=O)N(c3ccc(C)cc3)C2=O)cc1
# 214  CN1C(=O)N(c2cccc(C(F)(F)F)c2)C2=C(C(=O)CC2)C1c...
# 215         CC(SC(=O)c1cccs1)C(=O)NCC(=O)N1CSCC1C(=O)O
#
#                      stand_inchi      chembl_id  tid            pref_name  \
# 0    XVAKYHYZPKKXPJ-UHFFFAOYSA-N  CHEMBL3926578  235  Leukocyte elastase
# 1    GVZLHJFVWYZJOL-UHFFFAOYSA-N  CHEMBL3899195  235  Leukocyte elastase
# 2    MBIXKVGDRHLSCV-UHFFFAOYSA-N  CHEMBL3906862  235  Leukocyte elastase
# 3    YYSDWURRUMMAIG-UHFFFAOYSA-N  CHEMBL4790048  235  Leukocyte elastase
# 4    FFGCQYSSTYWKTM-UHFFFAOYSA-N  CHEMBL3983194  235  Leukocyte elastase
# ..                           ...            ...  ...                  ...
# 211  FPTMCPUSBLSGFP-UHFFFAOYSA-N  CHEMBL3956044  235  Leukocyte elastase
# 212  YAQCMERNUDLGCS-UHFFFAOYSA-N  CHEMBL4280854  235  Leukocyte elastase
# 213  AZZFGWWOGRBVOV-UHFFFAOYSA-N   CHEMBL296771  235  Leukocyte elastase
# 214  OZHWFTPSRFSWRF-UHFFFAOYSA-N  CHEMBL3928282  235  Leukocyte elastase
# 215  OFCXTUWNBCBZFB-UHFFFAOYSA-N   CHEMBL293138  235  Leukocyte elastase
#
#                                        scaffolds_csk  \
# 0                  C1CCC(C2CCC(C3CCCCC3)C3CCCC23)CC1
# 1          C1CCC(C2CCCC(CCCC3CCC(CC4CCCC4)CC3)C2)CC1
# 2                    C1CCC(CCCC2CCCC(C3CCCCC3)C2)CC1
# 3                           C1CCC(CC2CCC3CCCCC32)CC1
# 4        C1CCC(CCC2CC(C3CCCCC3)C3CCCC3C2C2CCCCC2)CC1
# ..                                               ...
# 211              C1CCC(C2CCC(C3CCCCC3CCC3CC3)CC2)CC1
# 212                C1CCC(CCC2CC(CC3CC3)C3CCCCC23)CC1
# 213                       C1CCC(C2CC(C3CCCCC3)C2)CC1
# 214  C1CCC(C2CCC(C3CCCCC3CC3CC4CCCCC4C3)C3CCCC23)CC1
# 215                          C(CCCC1CCCC1)CCCC1CCCC1
#
#                                                    mfp  clusters
# 0    <rdkit.DataStructs.cDataStructs.ExplicitBitVec...         0
# 1    <rdkit.DataStructs.cDataStructs.ExplicitBitVec...         1
# 2    <rdkit.DataStructs.cDataStructs.ExplicitBitVec...         1
# 3    <rdkit.DataStructs.cDataStructs.ExplicitBitVec...         4
# 4    <rdkit.DataStructs.cDataStructs.ExplicitBitVec...         1
# ..                                                 ...       ...
# 211  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...         2
# 212  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...         4
# 213  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...         1
# 214  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...         0
# 215  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...         3
#
# [216 rows x 12 columns]

# %%
df_0 = [(AllChem.GetMorganFingerprintAsBitVect\
                    (Chem.MolFromSmiles(x),10, nBits=2048)) for x in df[df.clusters==0].scaffolds_csk]
df_1 = [(AllChem.GetMorganFingerprintAsBitVect\
                    (Chem.MolFromSmiles(x),10, nBits=2048)) for x in df[df.clusters==1].scaffolds_csk.tolist()]
df_2 = [(AllChem.GetMorganFingerprintAsBitVect\
                    (Chem.MolFromSmiles(x),10, nBits=2048)) for x in df[df.clusters==2].scaffolds_csk.tolist()]
df_3 = [(AllChem.GetMorganFingerprintAsBitVect\
                    (Chem.MolFromSmiles(x),10, nBits=2048)) for x in df[df.clusters==3].scaffolds_csk.tolist()]
df_4 = [(AllChem.GetMorganFingerprintAsBitVect\
                    (Chem.MolFromSmiles(x),10, nBits=2048)) for x in df[df.clusters==4].scaffolds_csk.tolist()]

# %%
all_df = [df_0,df_1,df_2,df_3,df_4]
results = {}
results['index'] = ['cluster_0_max', 'cluster_1_max', 'cluster_2_max', 'cluster_3_max', 'cluster_4_max']
results['cluster_0'] = []
results['cluster_1'] = []
results['cluster_2'] = []
results['cluster_3'] = []
results['cluster_4'] = []

for y in range(5):
    for x in range(5):
        if x == y:
            results[f"cluster_{y}"].append("-")
        else:
            unique_combinations_0 = []
            for i in range(len(all_df[y])):
                for j in range(len(all_df[x])):
                    scaf_1 = all_df[y][i]
                    scaf_2 = all_df[x][j]
                    tanimoto = DataStructs.TanimotoSimilarity(scaf_1,scaf_2)
                    #print(DataStructs.TanimotoSimilarity(scaf_1,scaf_2))
                    #print(DataStructs.TanimotoSimilarity(scaf_2,scaf_1))
                    unique_combinations_0.append(tanimoto)
            max = np.array(unique_combinations_0).max()
            results[f"cluster_{y}"].append(max)

# %%
results
# Out:
# {'index': ['cluster_0_max',
#   'cluster_1_max',
#   'cluster_2_max',
#   'cluster_3_max',
#   'cluster_4_max'],
#  'cluster_0': ['-',
#   0.7333333333333333,
#   0.6161616161616161,
#   0.34782608695652173,
#   0.8791208791208791],
#  'cluster_1': [0.7333333333333333,
#   '-',
#   0.9733333333333334,
#   0.5714285714285714,
#   0.918918918918919],
#  'cluster_2': [0.6161616161616161,
#   0.9733333333333334,
#   '-',
#   0.6017699115044248,
#   0.918918918918919],
#  'cluster_3': [0.34782608695652173,
#   0.5714285714285714,
#   0.6017699115044248,
#   '-',
#   0.4336283185840708],
#  'cluster_4': [0.8791208791208791,
#   0.918918918918919,
#   0.918918918918919,
#   0.4336283185840708,
#   '-']}

# %%
dfff = pd.DataFrame.from_dict(results).set_index('index')
dfff
#dfff.to_csv(f"data/information_about_clusters/{receptor}/max_value_between_clusters.csv")

# %%
a = list(itertools.permutations(df,2))
        for x in a:
            start_id = x[0]
            stop_id = x[1]

# %%
dff =[1,2,3,4,5]
dff_1 = [3,5,7]

# %%
a = list(itertools.combinations(dff,2))
a
# Out:
# [(1, 2),
#  (1, 3),
#  (1, 4),
#  (1, 5),
#  (2, 3),
#  (2, 4),
#  (2, 5),
#  (3, 4),
#  (3, 5),
#  (4, 5)]

# %%
unique_combinations = []
for i in range(len(dff)):
    for j in range(len(dff_1)):
        unique_combinations.append((dff[i], dff_1[j]))
 
print(unique_combinations)
# Out:
# [(1, 3), (1, 5), (1, 7), (2, 3), (2, 5), (2, 7), (3, 3), (3, 5), (3, 7), (4, 3), (4, 5), (4, 7), (5, 3), (5, 5), (5, 7)]

# %% [markdown]
# # Create statistic inside cluster

# %%
receptor = 'Leukocyte_elastase'
df = pd.read_csv(f"data/input_recall_sets_new/{receptor}/{receptor}_split_to_clusters_using_KMedoids.csv")
df
# Out:
#      molregno stand_type  pchembl_value  stand_value  \
# 0     2135949       IC50           7.18         66.0
# 1     2108566       IC50           7.70         20.0
# 2     2116233       IC50           7.38         42.0
# 3     2526639       IC50           7.05         89.0
# 4     2192565       IC50           8.42          3.8
# ..        ...        ...            ...          ...
# 211   2165415       IC50           8.52          3.0
# 212   2320305       IC50           6.10        800.0
# 213     69173       IC50           6.64        230.0
# 214   2137653       IC50           8.41          3.9
# 215     88510       IC50          10.00          0.1
#
#                                       canonical_smiles  \
# 0    CC1CC2=C(C1=O)C(c1ccc(C#N)cc1)NC(=O)N2c1cccc(C...
# 1    Cc1c(-c2cccc(C(F)(F)F)c2)c(=O)c(C(=O)NCc2ccc(C...
# 2    COCCn1cc(C(=O)NCc2ccc(S(C)(=O)=O)cc2)c(=O)c(-c...
# 3                   Cc1cccc(C(=O)n2cc(C#N)c3ncccc32)c1
# 4    N#Cc1ccc(C2C3=C(CCC3=O)N(c3cccc(C(F)(F)F)c3)C(...
# ..                                                 ...
# 211  CCOC(=O)C1=C(C)N(c2cccc(C(F)(F)F)c2)C(=O)N(C)C...
# 212            O=C(Nc1ccccc1)c1cn(C(=O)C2CC2)c2ncccc12
# 213               Cc1ccc(N2C(=O)N(c3ccc(C)cc3)C2=O)cc1
# 214  CN1C(=O)N(c2cccc(C(F)(F)F)c2)C2=C(C(=O)CC2)C1c...
# 215         CC(SC(=O)c1cccs1)C(=O)NCC(=O)N1CSCC1C(=O)O
#
#                      stand_inchi      chembl_id  tid            pref_name  \
# 0    XVAKYHYZPKKXPJ-UHFFFAOYSA-N  CHEMBL3926578  235  Leukocyte elastase
# 1    GVZLHJFVWYZJOL-UHFFFAOYSA-N  CHEMBL3899195  235  Leukocyte elastase
# 2    MBIXKVGDRHLSCV-UHFFFAOYSA-N  CHEMBL3906862  235  Leukocyte elastase
# 3    YYSDWURRUMMAIG-UHFFFAOYSA-N  CHEMBL4790048  235  Leukocyte elastase
# 4    FFGCQYSSTYWKTM-UHFFFAOYSA-N  CHEMBL3983194  235  Leukocyte elastase
# ..                           ...            ...  ...                  ...
# 211  FPTMCPUSBLSGFP-UHFFFAOYSA-N  CHEMBL3956044  235  Leukocyte elastase
# 212  YAQCMERNUDLGCS-UHFFFAOYSA-N  CHEMBL4280854  235  Leukocyte elastase
# 213  AZZFGWWOGRBVOV-UHFFFAOYSA-N   CHEMBL296771  235  Leukocyte elastase
# 214  OZHWFTPSRFSWRF-UHFFFAOYSA-N  CHEMBL3928282  235  Leukocyte elastase
# 215  OFCXTUWNBCBZFB-UHFFFAOYSA-N   CHEMBL293138  235  Leukocyte elastase
#
#                                        scaffolds_csk  \
# 0                  C1CCC(C2CCC(C3CCCCC3)C3CCCC23)CC1
# 1          C1CCC(C2CCCC(CCCC3CCC(CC4CCCC4)CC3)C2)CC1
# 2                    C1CCC(CCCC2CCCC(C3CCCCC3)C2)CC1
# 3                           C1CCC(CC2CCC3CCCCC32)CC1
# 4        C1CCC(CCC2CC(C3CCCCC3)C3CCCC3C2C2CCCCC2)CC1
# ..                                               ...
# 211              C1CCC(C2CCC(C3CCCCC3CCC3CC3)CC2)CC1
# 212                C1CCC(CCC2CC(CC3CC3)C3CCCCC23)CC1
# 213                       C1CCC(C2CC(C3CCCCC3)C2)CC1
# 214  C1CCC(C2CCC(C3CCCCC3CC3CC4CCCCC4C3)C3CCCC23)CC1
# 215                          C(CCCC1CCCC1)CCCC1CCCC1
#
#                                                    mfp  clusters
# 0    <rdkit.DataStructs.cDataStructs.ExplicitBitVec...         0
# 1    <rdkit.DataStructs.cDataStructs.ExplicitBitVec...         1
# 2    <rdkit.DataStructs.cDataStructs.ExplicitBitVec...         1
# 3    <rdkit.DataStructs.cDataStructs.ExplicitBitVec...         4
# 4    <rdkit.DataStructs.cDataStructs.ExplicitBitVec...         1
# ..                                                 ...       ...
# 211  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...         2
# 212  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...         4
# 213  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...         1
# 214  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...         0
# 215  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...         3
#
# [216 rows x 12 columns]

# %%
df_0 = [(AllChem.GetMorganFingerprintAsBitVect\
                    (Chem.MolFromSmiles(x),10, nBits=2048)) for x in df[df.clusters==0].scaffolds_csk]
df_1 = [(AllChem.GetMorganFingerprintAsBitVect\
                    (Chem.MolFromSmiles(x),10, nBits=2048)) for x in df[df.clusters==1].scaffolds_csk.tolist()]
df_2 = [(AllChem.GetMorganFingerprintAsBitVect\
                    (Chem.MolFromSmiles(x),10, nBits=2048)) for x in df[df.clusters==2].scaffolds_csk.tolist()]
df_3 = [(AllChem.GetMorganFingerprintAsBitVect\
                    (Chem.MolFromSmiles(x),10, nBits=2048)) for x in df[df.clusters==3].scaffolds_csk.tolist()]
df_4 = [(AllChem.GetMorganFingerprintAsBitVect\
                    (Chem.MolFromSmiles(x),10, nBits=2048)) for x in df[df.clusters==4].scaffolds_csk.tolist()]

# %%
tanimoto_array = {
"index": ["mean", "min", "max"],
"cluster_0" : [],
"cluster_1" : [],
"cluster_2" : [],
"cluster_3" : [],
"cluster_4" : [],
}

df_all = [df_0, df_1, df_2, df_3, df_4]
for x in range(5):
    a = list(itertools.combinations(df_all[x],2))
    arr = []
    for i in a:
    
        tanimoto = DataStructs.TanimotoSimilarity(i[0],i[1])
        arr.append(tanimoto)
    tanimoto_array[f"cluster_{x}"].append(np.array(arr).mean())
    tanimoto_array[f"cluster_{x}"].append(np.array(arr).min())
    tanimoto_array[f"cluster_{x}"].append(np.array(arr).max())

# %%
tanimoto_array
# Out:
# {'index': ['mean', 'min', 'max'],
#  'cluster_0': [0.23029342266808148, 0.06164383561643835, 0.9811320754716981],
#  'cluster_1': [0.2236857710009376, 0.061224489795918366, 0.9666666666666667],
#  'cluster_2': [0.23487403269231502, 0.08391608391608392, 0.9782608695652174],
#  'cluster_3': [0.1983618482477161, 0.015306122448979591, 1.0],
#  'cluster_4': [0.20949814592237753, 0.055776892430278883, 0.9866666666666667]}

# %%
df = pd.DataFrame.from_dict(tanimoto_array).set_index('index')

# %%
df.to_csv(f"data/information_about_clusters/{receptor}/statistic_incide_cluster.csv")

# %%
from rdkit import Chem
from rdkit.Chem import AllChem
import numpy as np
from scipy.stats import entropy  # Pro výpočet KL divergence
import sys
import pandas as pd

def smiles_to_fingerprint(smiles_list, radius=3, n_bits=2048):
    """Převod seznamu SMILES na Morgan Fingerprinty."""
    fingerprints = []
    for smiles in smiles_list:
        mol = Chem.MolFromSmiles(smiles)
        if mol is not None:
            fp = AllChem.GetMorganFingerprintAsBitVect(mol, radius, nBits=n_bits)
            fingerprints.append(fp)
    return np.array(fingerprints)

def calculate_distribution(fingerprints):
    """Vypočítá distribuci (normalizovaný histogram) fingerprintů."""
    summed_fp = np.sum(fingerprints, axis=0)
    distribution = summed_fp / np.sum(summed_fp)  # Normalizace
    return distribution

def calculate_kl_divergence(distribution_p, distribution_q):
    """Spočítá KL divergenci mezi dvěma distribučními pravděpodobnostmi."""
    distribution_p = smooth_distribution(distribution_p)
    distribution_q = smooth_distribution(distribution_q)
    return entropy(distribution_p, distribution_q)


def smooth_distribution(distribution, epsilon=1e-10):
    """Zajistí, že v distribuci nejsou nulové hodnoty."""
    return distribution + epsilon

# %%
type_cluster = 'dis'
num = 0
generator = 'Molpher'

output_set = pd.read_csv(f"data/output_sets/Glucocorticoid_receptor/cOS_{generator}_{type_cluster}_{num}_one_column.csv", header=None)[0].tolist()

recall_set = pd.read_csv(f"data/input_recall_sets/Glucocorticoid_receptor/cRS_Glucocorticoid_receptor_{type_cluster}_{num}.csv", header=None)[0].tolist()

print("----------------------------------------------------------------------------------------------------------------")
print(f"{generator} {type_cluster} {num}")

# Převod SMILES na Fingerprinty
fingerprints_1 = smiles_to_fingerprint(output_set)
fingerprints_2 = smiles_to_fingerprint(recall_set)
# Out:
# ----------------------------------------------------------------------------------------------------------------
# Molpher dis 0

# %%
len(fingerprints_1)
# Out:
# 916551

# %%
len(output_set)
# Out:
# 916551

# %%
# Výpočet distribuce
distribution_1 = calculate_distribution(fingerprints_1)
distribution_2 = calculate_distribution(fingerprints_2)

# %%
distribution_1
# Out:
# array([0.00010575, 0.00523781, 0.00105501, ..., 0.0001443 , 0.00038624,
#        0.00015004])

# %%
distribution_2
# Out:
# array([0.        , 0.00140287, 0.00024398, ..., 0.        , 0.00079292,
#        0.00012199])

# %%
# Výpočet KL divergence
kl_divergence = calculate_kl_divergence(distribution_1, distribution_2)

print(f"KL Divergence: {kl_divergence}")
# Out:
# KL Divergence: 2.6624849764176273

# %%
df_KL = pd.DataFrame(columns = ['generator', 'KL'])
df_KL
# Out:
# Empty DataFrame
# Columns: [generator, KL]
# Index: []

# %%
df_KL.loc[len(df_KL)] = ['Molpher', kl_divergence]
df_KL
# Out:
#   generator        KL
# 0   Molpher  2.662485

# %%
import pandas as pd

# %%
df = pd.read_csv("../../../reinvent/new/REINVENT4/recall_metrics/staged_learning/results/dis_0/102928.lich-compute.vscht.cz/RL_dis_0_1.csv")
df
# Out:
#         Agent    Prior   Target     Score  \
# 0     27.4591  27.4591  54.9570  0.643875
# 1     26.8171  26.8171  48.5986  0.589185
# 2     29.6907  29.6907  50.1121  0.623460
# 3     23.7634  23.7634  77.0151  0.787332
# 4     25.4805  25.4805  62.8888  0.690385
# ...       ...      ...      ...       ...
# 6395  24.9883  24.9154  59.1465  0.656734
# 6396  49.5664  49.4721  59.4203  0.850722
# 6397  26.0916  26.6511  61.8992  0.691800
# 6398  25.1416  24.7231  74.1666  0.772576
# 6399  26.5201  26.5557  72.8418  0.776543
#
#                                                  SMILES  SMILES_state  \
# 0                     CCOCn1c(N)c(CC(=O)O)c(=O)[nH]c1=O             1
# 1                                CC(C)(C)C#CC=NOCC(N)=O             1
# 2                   CC(C)(C)[N+]([O-])=CC1CC1CCc1ccccc1             1
# 3         Cc1cn(C2CC(O)C(COC(CO)CC(C)C)O2)c(=O)[nH]c1=O             1
# 4                             NC(=O)COc1ccccc1OC(F)(F)F             1
# ...                                                 ...           ...
# 6395            c1cncc(N=c2[nH]c(-c3cccnc3)cn3ccnc23)c1             1
# 6396  CCCOc1ccc(S(=O)(=O)N(c2cccc(-c3ccccc3)c2)C2CCN...             1
# 6397             N#CC(C(=N)CC(=O)c1ccccc1)c1nc2ccccc2s1             1
# 6398           O=C(O)c1cccc(NCc2nnc(-c3ccc(Cl)cc3)o2)c1             1
# 6399  CCOC(=O)c1sc(NC(=O)c2cccc([N+](=O)[O-])c2)c(C(...             1
#
#        SAScore  SAScore (raw)      QSAR  QSAR (raw)  step
# 0     0.896620         2.7280  0.558689      5.2561     1
# 1     0.799100         3.5659  0.517047      5.0741     1
# 2     0.807761         3.5070  0.557963      5.2529     1
# 3     0.746926         3.8867  0.805311      6.5416     1
# 4     0.948611         1.9161  0.602490      5.4515     1
# ...        ...            ...       ...         ...   ...
# 6395  0.864962         3.0538  0.583619      5.3666   100
# 6396  0.873300         2.9750  0.841225      6.8103   100
# 6397  0.873419         2.9738  0.626023      5.5594   100
# 6398  0.945798         1.9766  0.708415      5.9638   100
# 6399  0.936565         2.1562  0.716624      6.0073   100
#
# [6400 rows x 11 columns]

# %%
df['QSAR (raw)'].max()
# Out:
# 7.6808

# %%
df['QSAR'].max()
# Out:
# 0.2038987

# %%
len(df[df['QSAR (raw)'] >= 7])
# Out:
# 3221

# %%
df[(df['SAScore'] >= 0.1) & (df['SAScore'] <= 0.2)]
# Out:
#           Agent    Prior   Target     Score  \
# 16      67.5277  67.5277 -13.6507  0.420915
# 79      43.0127  43.0127   9.0473  0.406719
# 90      39.6816  39.6816   6.4074  0.360070
# 197     33.3440  33.3440  15.6140  0.382484
# 724     63.5320  63.4205 -17.9216  0.355460
# ...         ...      ...      ...       ...
# 142490  50.1112  48.2692   2.4903  0.396559
# 145338  37.5192  36.1162  18.3208  0.425289
# 146368  32.9705  34.2837   9.6776  0.343448
# 151713  46.9294  44.6242  10.4244  0.430067
# 152635  48.3042  47.1535   3.9168  0.398986
#
#                                                    SMILES  SMILES_state  \
# 16      C=C1CC(CC=CCC(C)C2=CC3(COC(C)(O)C3=CC)C(=O)CN2...             1
# 79              COC(C)C(C)C1=CC2(OC1C)C(C)C(=O)NC21CCCCC1             1
# 90      C=C(C=CC=C(C)C(=O)O)C1CCC2(C)COC3CC(O)C2C1(C)C...             1
# 197                      CC1=CSC2=NCC3(CC12)NN=C(C(C)C)O3             1
# 724     COC(=O)CNC(=O)N(C)N=C1C2C(O)C(O)C(NS(=O)(=O)C3...             1
# ...                                                   ...           ...
# 142490  Cc1cc2c(C34CC3CN(C(=O)OCc3ccccc3)C4=O)n1[SH](c...             1
# 145338  CC1(C)[N+]([O-])=c2ccc(C=C3C(O)C4CCN3C4=O)cc2=...             1
# 146368  O=C(CC1CCc2[nH]c3c4c2C(=O)N(CCCN2CCOCC2)C(=O)C...             1
# 151713        CC(C)C12OC(c3ccoc3Br)C1(C)CCC13CC(O)C1CCC32             1
# 152635  C=C1C(O)CC(O)C2C=C(C)C3(CC(C)C(OC(=O)c4ccoc4)C...             1
#
#          SAScore  SAScore (raw)      QSAR  QSAR (raw)  step
# 16      0.180605         5.6568  0.980977      6.7124     1
# 79      0.185768         5.6418  0.890468      5.9101     1
# 90      0.159789         5.7208  0.811387      5.6337     1
# 197     0.178483         5.6630  0.819651      5.6575     1
# 724     0.128800         5.8302  0.980990      6.7127     2
# ...          ...            ...       ...         ...   ...
# 142490  0.161213         5.7163  0.975473      6.5996   279
# 145338  0.190897         5.6272  0.947476      6.2562   284
# 146368  0.120392         5.8637  0.979766      6.6851   286
# 151713  0.193198         5.6208  0.957345      6.3511   297
# 152635  0.160730         5.7178  0.990418      7.0144   299
#
# [150 rows x 11 columns]

# %%
import matplotlib.pyplot as plt
plt.hist(df['QSAR'], bins=30, range=(0, 1), color='blue', alpha=0.7)
plt.title("Distribution of pChEMBL Scores")
plt.xlabel("QSAR")
plt.ylabel("Frequency")
plt.show()

# %%
df_gb = pd.read_csv("../../../gb_ga/GB_GA/results/dis_0/102935.lich-compute.vscht.cz/cOS_GB_GA_dis_0_mutation_rate_0.01_one_column.csv", header = None)
df_gb
# Out:
#                                                          0
# 0        Fc1ccc(-n2ncc3cc(-c4ccc(Nc5cccc6ccccc56)cc4C(F...
# 1        COc1ccc(-c2ccc(N=C(C)c3ccsc3/C=C3\Oc4ccc(O)c(O...
# 2        COc1c(-c2ccccc2C)ccc2c1-c1ccc3c(c1/C(=C/c1cccc...
# 3        COc1c(O)ccc2c1-c1ccc3c(c1/C(=C/c1cccc(-c4cc(Cl...
# 4        Cc1c(N(Cc2ccccc2)Cc2ccccc2Cl)cccc1C(C)(C)c1ccc...
# ...                                                    ...
# 1094574  COC=CC1=CC=C(/C=C2\OC3=C(C(OC(C)(F)F)=CC=C3)C3...
# 1094575  Cc1cccc(C(F)(F)c2ccnc3c(C)cc(-c4cccc5cc[nH]c45...
# 1094576              CCCN(Cc1ccccc1-c1ccccc1F)c1ccc(F)cc1C
# 1094577  Cc1cc(Cl)cc(CC(C)(F)c2c(Cc3ccc(O)c4ccccc34)cc(...
# 1094578  CC=Cc1ccc(CN(c2cccc3c2CC(c2ccc(C)cc2C)CC3)C(C)...
#
# [1094579 rows x 1 columns]

# %%
len(set(df_gb[0].tolist()))
# Out:
# 275419
